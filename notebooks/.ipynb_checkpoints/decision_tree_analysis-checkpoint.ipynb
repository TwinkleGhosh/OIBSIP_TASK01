# %%
# Fix path
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# Step 1: Imports
from src.data_preprocessing import load_and_clean_data
from src.model_training import train_model, save_model
from src.evaluation import evaluate_model
from src.visualization import visualize_tree
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Step 1: Imports
# ----> 2 from src.data_preprocessing import load_and_clean_data
#       3 from src.model_training import train_model, save_model
#       4 from src.evaluation import evaluate_model
#       5 from src.visualization import visualize_tree
#
# File c:\Users\Admin\OneDrive\Desktop\desision_tree_project\src\data_preprocessing.py:1
# ----> 1 import pandas as pd
#       4 def load_and_clean_data(path):
#       5     # Column names for wine dataset
#       6     columns = [
#       7         "target",
#       8         "alcohol",
#    (...)     20         "proline",
#      21     ]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Step 2: Load Data
df = load_and_clean_data("../data/raw/wine.data")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Step 2: Load Data
# ----> 2 df = load_and_clean_data("../data/raw/wine.data")
#       3 df.head()
#
# NameError: name 'load_and_clean_data' is not defined

# %%
# Step 3: Train Model
model, X_test, y_test = train_model(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Step 3: Train Model
# ----> 2 model, X_test, y_test = train_model(df)
#
# NameError: name 'train_model' is not defined

# %%
# Step 4: Evaluate
evaluate_model(model, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Step 4: Evaluate
# ----> 2 evaluate_model(model, X_test, y_test)
#
# NameError: name 'evaluate_model' is not defined

# %%
# Step 5: Save Model
save_model(model, "../models/decision_tree_model.pkl")

# %%
# Step 6: Visualize Tree
visualize_tree(
    model,
    feature_names=df.drop("target", axis=1).columns,
    save_path="../images/tree_visualization.png"
)
