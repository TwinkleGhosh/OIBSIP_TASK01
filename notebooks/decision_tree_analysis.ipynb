# %%
# Fix path
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# Step 1: Imports
from src.data_preprocessing import load_and_clean_data
from src.model_training import train_model, save_model
from src.evaluation import evaluate_model
from src.visualization import visualize_tree

# %%
# Step 2: Load Data
df = load_and_clean_data("../data/raw/wine.csv")
df.head()
# Out:
#    target  alcohol  malic_acid   ash  alcalinity  magnesium  phenols  \
# 0       1    14.23        1.71  2.43        15.6        127     2.80
# 1       1    13.20        1.78  2.14        11.2        100     2.65
# 2       1    13.16        2.36  2.67        18.6        101     2.80
# 3       1    14.37        1.95  2.50        16.8        113     3.85
# 4       1    13.24        2.59  2.87        21.0        118     2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280_od315  proline
# 0         3.92     1065
# 1         3.40     1050
# ...

# %%
import os
path = "../data/raw/wine.data"
print("Is file:", os.path.isfile(path))
print("Is folder:", os.path.isdir(path))
# Out:
# Is file: False
# Is folder: False

# %%
# Step 2: Load Data
df = load_and_clean_data("../data/raw/wine.csv")
df.head()
# Out:
#    target  alcohol  malic_acid   ash  alcalinity  magnesium  phenols  \
# 0       1    14.23        1.71  2.43        15.6        127     2.80
# 1       1    13.20        1.78  2.14        11.2        100     2.65
# 2       1    13.16        2.36  2.67        18.6        101     2.80
# 3       1    14.37        1.95  2.50        16.8        113     3.85
# 4       1    13.24        2.59  2.87        21.0        118     2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280_od315  proline
# 0         3.92     1065
# 1         3.40     1050
# ...

# %%
# Step 3: Train Model
model, X_test, y_test = train_model(df)

# %%
# Step 4: Evaluate
evaluate_model(model, X_test, y_test)
# Out:
# Accuracy: 0.9444444444444444
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.93      0.96        14
#            2       0.88      1.00      0.93        14
#            3       1.00      0.88      0.93         8
#
#     accuracy                           0.94        36
#    macro avg       0.96      0.93      0.94        36
# weighted avg       0.95      0.94      0.94        36
# (0.9444444444444444,
#  '              precision    recall  f1-score   support\n\n           1       1.00      0.93      0.96        14\n           2       0.88      1.00      0.93        14\n           3       1.00      0.88      0.93         8\n\n    accuracy                           0.94        36\n   macro avg       0.96      0.93      0.94        36\nweighted avg       0.95      0.94      0.94        36\n')

# %%
# Step 5: Save Model
save_model(model, "../models/decision_tree_model.pkl")

# %%
# Step 6: Visualize Tree
visualize_tree(
    model,
    feature_names=df.drop("target", axis=1).columns,
    save_path="../images/tree_visualization.png"
)
